# %%
import pandas as pd
import pickle

# %%
x1=input('Vapor입력하시오')
x2=input('resist_target입력하시오')
x3=input('Line_CD입력하시오')
x4=input('UV_type입력하시오')
x5=input('Etching_rater입력하시오')
x6=input('thickness입력하시오')
x7=input('Temp_Etching입력하시오')
# Out:
# Vapor입력하시오204
# resist_target입력하시오4
# Line_CD입력하시오55
# UV_type입력하시오33
# Etching_rater입력하시오2
# thickness입력하시오H
# Temp_Etching입력하시오3

# %%
X_list = ['Vapor', 'resist_target', 'Line_CD', 'UV_type', 'Etching_rate', 'thickness', 'Temp_Etching']
input_data = pd.DataFrame([[x1, x2, x3, x4, x5, x6, x7]], columns=X_list)
input_data
# Out:
#   Vapor resist_target Line_CD UV_type Etching_rate thickness Temp_Etching
# 0   204             4      55      33            2         H            3

# %%
import pickle
from google.colab import drive

# Google Drive 마운트
drive.mount('/content/drive')


model=pickle.load( open('/content/drive/My Drive/model.sav', 'rb'))
model
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Ellipsis

# %%
model.predict(input_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-8a1cf96ca284> in <cell line: 0>()
# ----> 1 model.predict(input_data)
#
# AttributeError: 'ellipsis' object has no attribute 'predict'

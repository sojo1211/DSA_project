# %%
#모델을 불러와/세로운 값을 모델을 입력해 예측
import pickle
import pandas as pd
#코렙
from google.colab import files
from google.colab import drive

# Google Drive 마운트
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#모델을 불러오기
with open('/content/drive/MyDrive/DSA/model.sav', 'rb') as file:
    model = pickle.load(file)

# %%
#새로운 값 입력하기 input()
x1=int(input("계약기간을 입력하시오:"))
x2=int(input("월랜탈비용을 입력하시오:"))
x3=int(input("고객연령을 입력하시오:"))
x4=int(input("고객 신용등급을 입력하시오"))
input_data=[x1,x2,x3,x4]
# Out:
# 계약기간을 입력하시오:60
# 월랜탈비용을 입력하시오:9000
# 고객연령을 입력하시오:400
# 고객 신용등급을 입력하시오300

# %%
input_data
# Out:
# [60, 9000, 400, 300]

# %%
#입력받은 개별 값을 데이터 프레임 형태로 변환
new_input = pd.DataFrame([input_data], columns=['Term', "Amount_Month", "Age", "Credit_Rank"])

# %%
new_input
# Out:
#    Term  Amount_Month  Age  Credit_Rank
# 0    60          9000  400          300

# %%
#입력된 값을 이용해,예측수행
model.predict(new_input)
# Out:
# array([1])
